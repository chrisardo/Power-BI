# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisardo/Power-BI/blob/main/TEMA_8_CASO_REAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# [Sala Situcional COVID-19 Perú](https://covid19.minsa.gob.pe/sala_situacional.asp)

# %% [markdown]
# ```
# Muestras = SUMX(POSITIVIDAD_20022023, POSITIVIDAD_20022023[Muestras])
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Muestras x Región =
# CALCULATE
# (
#     SUM(POSITIVIDAD[Valor]),
#     POSITIVIDAD[Atributo]="MUESTRAS"
# )
# ```

# %% [markdown]
# ```
# Confirmados (+) x Región =
# CALCULATE
# (
#     SUM(POSITIVIDAD[Valor]),
#     POSITIVIDAD[Atributo]="CONFIRMADO (+)"
# )
# ```

# %% [markdown]
# ```
# Pacientes con Alta Médica =
# CALCULATE
# (
#     COUNTROWS(TB_SEGUIM_COVID19),
#     TB_SEGUIM_COVID19[evolucion]="alta" || TB_SEGUIM_COVID19[evolucion]="alta voluntaria"
# )
# ```
